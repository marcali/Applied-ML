# %% [markdown]
# <h3>TODO</h3>
# Fill in any place that says <code># YOUR CODE HERE</code> (make sure to remove the line <code>raise NotImplementedError()</code>).
#
# <h3>Suggestions</h3>
#
# - To speed up your code, think about how certain operations can be done at the same time.
# - Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
# - Double check your code does not have $\infty$-loops, these will crash the autograder.
#
# <h3>Rules</h3>
#
# - Blank cells in the notebook are hidden tests. **Do not delete, copy, paste, or alter these cells as this will cause the tests to fail automatically**.
# - Do not create multiple python notebooks (.ipynb files).
# - Do not import any new python packages (this may cause hidden tests to fail).
# - Each cell must run for less than 5 minutes (there exists a solution with full marks).
# - **Do not plagiarise!** We take violations of this very seriously. In previous years we have identified instances of plagiarism and reported them to the Senior Teaching & Learning Administrator.
# - If you are happy with your current grade you do not need to resubmit, the most recent grade from the autograder will be your final grade.

# %% [markdown]
# ---

# %%
import numpy as np
np.random.seed(0)
from numpy.matlib import repmat
import sys
import time
from l2distance import l2distance
import visclassifier
import matplotlib
import matplotlib.pyplot as plt
import traceback

import pylab
from matplotlib.animation import FuncAnimation

#new torch imports
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

#misc imports
import random

# %matplotlib inline

# %% [markdown]
# <h3>Introduction</h3>
# In this project, you will implement a linear support vector machine and one operating in kernel space. For this you will need to formulate the primal and dual optimization problems as quadratic programs. For this, we will be dipping into the shallow end with Course staffs' favorite ML framework: PyTorch!
#
# For full documentation and details, here is their site https://pytorch.org/. PyTorch is an open source machine learning library based on the Torch library, used for applications such as computer vision and natural language processing, primarily developed by Facebook's AI Research lab. Pytorch is very neat because, as you have seen your assignments, in order to do gradient descent we've had to calculate gradient manually. No more! Pytorch performs automatic differentation, as long as we use their functions in our code.
#
# Note: Because we are working with Pytorch functions and Modules, we will be using excusively Pytorch tensors instead of numpy arrays. This allows us to multiply/use torch parameter objects with our data directly. Pytorch tensors carry most of the same functionality as numpy arrays.

# %% [markdown]
# We will start with a simple example of PyTorch, where we use gradient descent to find the parameters of a simple linear regression problem.

# %%
def gen_regression_data(num_samples = 10000, ndims=1):
    # generate random x samples for training and test sets
    xTr = torch.rand(num_samples, ndims)
    xTe = torch.rand(int(num_samples * 0.1), ndims)
    
    # construct random w and b vectors
    gt_w = torch.randn(ndims, 1)
    gt_b = torch.randn(1)
    
    # gaussian noise for linear regression
    noise = np.random.normal(size=(num_samples, 1)) * 0.02
    test_noise = np.random.normal(size=(int(num_samples * 0.1), 1)) * 0.02
    
    # add noise on the labels for the training set
    yTr = xTr @ gt_w + gt_b + noise
    yTe = xTe @ gt_w + gt_b + test_noise
    
    return xTr, xTe, yTr, yTe, gt_w, gt_b

# %%
lr_xTr, lr_xTe, lr_yTr, lr_yTe, gt_w, gt_b = gen_regression_data(num_samples = 1000, ndims=1)

# %% [markdown]
# Now we will create our PyTorch model. PyTorch models inherit the class torch.nn.module, and you need to implement the function forward which is equivalent to a forward pass. Usually, you feed in batch of x samples as input and you get batch of outputs, but you could pass other parameters as well if needed. Every torch module will implement two functions. __init__ its constructor, and __forward__ which defines what happens when you call the module.
#
# Note we define two fields of the <code>LinearRegressionModel</code>:
# * <code>self.w</code>: The weight vector of the linear regression model. This is updated automatically by Pytorch in our training loop because we define it as a nn.Parameter (note requires_grad=True). Additionally <code>torch.randn(ndims, 1)</code> gives us an initialization for this weight vector.
# * <code>self.b</code>: The bias of the linear regression model. This is also updated automatically by Pytorch in our training loop.

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self, ndims):
        super(LinearRegressionModel, self).__init__()
        """ pytorch optimizer checks for the properties of the model, and if
            the torch.nn.Parameter requires gradient, then the model will update
            the parameters automatically.
        """
        self.w = nn.Parameter(torch.randn(ndims, 1), requires_grad=True)
        self.b = nn.Parameter(torch.randn(1), requires_grad=True)
    
    def forward(self, x):
        return x @ self.w + self.b

# %% [markdown]
# For this example we use our familiar mean-squared error loss.

# %%
def mse_loss(y_pred, y_true):
    square_diff = torch.square((y_pred-y_true))
    mean_error = 0.5 * torch.mean(square_diff)
    return mean_error

# %% [markdown]
# Here is a generic training loop in Pytorch, this will be very useful for you in your assignment. We have supplied comments per line to help walk you through what each different part does.

# %%
def train_regression_model(xTr, yTr, num_epochs, reg_param, lr=1e-2, print_freq=100):
    ndims = xTr.shape[1]
    
    model = LinearRegressionModel(ndims)  # initialize the model
    optimizer = optim.SGD(model.parameters(), lr=lr)  # create an SGD optimizer for the model parameters
    
    for epoch in range(num_epochs):
        # need to zero the gradients in the optimizer so we don't
        # use the gradients from previous iterations
        optimizer.zero_grad()  
        pred = model.forward(xTr)  # compute model predictions
        loss = mse_loss(pred, yTr) + reg_param * torch.norm(model.w)
        loss.backward()  # compute the gradient wrt loss
        optimizer.step()  # performs a step of gradient descent
        if (epoch + 1) % print_freq == 0:
            print('epoch {} loss {}'.format(epoch+1, loss.item()))
    
    return model  # return trained model

# %%
model = train_regression_model(lr_xTr, lr_yTr, num_epochs=2000, reg_param=0.001, lr=1e-2)
avg_test_error = mse_loss(model.forward(lr_xTe), lr_yTe)
print('avg test error', avg_test_error.item())
# Out:
# epoch 100 loss 0.07743458641491492
# epoch 200 loss 0.06017601641312721
# epoch 300 loss 0.052247913067484435
# epoch 400 loss 0.04584138769817798
# epoch 500 loss 0.040254813989276585
# epoch 600 loss 0.03534875723899529
# epoch 700 loss 0.031037627892388002
# epoch 800 loss 0.027249079599731572
# epoch 900 loss 0.02391974479792476
# epoch 1000 loss 0.02099396594155546
# epoch 1100 loss 0.018422822882883466
# epoch 1200 loss 0.016163328856814606
# epoch 1300 loss 0.014177706692276434
# epoch 1400 loss 0.0124327665049586
# epoch 1500 loss 0.010899332503396133
# epoch 1600 loss 0.009551766556038753
# epoch 1700 loss 0.008367540778883345
# epoch 1800 loss 0.00732685633041712
# epoch 1900 loss 0.006487538445632534
# epoch 2000 loss 0.0057733140801884365
# avg test error 0.005568665361582833

# %% [markdown]
# Now, we have a trained model object that we can predict with by passing in input data via model.forward(x). Let's visualize how good of a fit our line is to the data!

# %%
plt.plot(lr_xTr, model.forward(lr_xTr).detach(),linewidth=5.0, color="red", label="Prediction Line")
plt.scatter(lr_xTr, lr_yTr, label="Train Points")
plt.scatter(lr_xTe, lr_yTe, label="Test Points")
plt.legend()
plt.show()

# %% [markdown]
# For the following assignment there are a bunch of PyTorch specfic functions that we believe will be very helpful for you. Those are:
#
# * <code>torch.clamp(input, min=None, max=None, *, out=None) </code>: Clamps all elements in input into the range [min, max]
#
# * <code>torch.sum(input, *, dtype=None) </code>: Returns the sum of all elements in the input tensor.
#
# * <code>torch.mean(input, *, dtype=None)</code>: Returns the mean value of all elements in the input tensor.
#
# * <code>torch.pow(input, exponent, *, out=None)</code>: Takes the power of each element in input with exponent and returns a tensor with the result.
#
# * <code>torch.exp(input, *, out=None)</code>: Returns a new tensor with the exponential of the elements of the input tensor.

# %% [markdown]
# <h3> Linear classification</h3>
#
# <p> The first part of the assignment is to implement a linear support vector machine. In order to do this, we are going to generate random data to classify:
# </p>

# %%
def genrandomdata(n=100,b=0.):
    # generate random data and linearly separable labels
    xTr = np.random.randn(n, 2)
    # defining random hyperplane
    w0 = np.random.rand(2, 1)
    # assigning labels +1, -1 labels depending on what side of the plane they lie on
    yTr = np.sign(np.dot(xTr, w0)+b).flatten()
    return torch.from_numpy(xTr).float(), torch.from_numpy(yTr).float()

# %% [markdown]
# <p>Remember the SVM primal formulation
# $$\begin{aligned}
#              &\min_{\mathbf{w},b,\xi} \|\mathbf{w}\|^2_2+C \sum_{i=1}^n \xi_i\\
#        & \text{such that }  \ \forall i:\\
#              & y_i(\mathbf{w}^\top \mathbf{x}_i+b)\geq 1-\xi_i\\
#              & \xi_i\geq 0.\\
# \end{aligned}
# $$
# You will need to implement  the function <code>primalSVM</code>, which takes in training data <code>xTr</code> ($n\times d$) and labels <code>yTr</code> ($n$) with <code>yTr[i]</code>$\in \{-1,1\}$. Note that we aren't doing linear programming, this is gradient descent optimization so the constraints are something we do not worry about.</p>

# %% [markdown]
# To warm up, implement <code>hinge_loss</code>, which calculates the loss described in $\sum_{i=1}^n \xi_i$. Working with torch tensors is a lot like working with numpy tensors, think about the best way to do tensor on tensor operations. <b>This method requires no loops</b>.
#
# Hint: <code>torch.clamp</code> might be useful here

# %%
def hinge_loss(y_pred, y_true):
    return torch.clamp(1 - y_true * y_pred, min=0)

# %% [markdown]
# Next, implement <code>LinearSVM</code>. This is a module (similar to the one in the example above) which initializes a linear classifer in dimension <code>dim</code>. In this module, you will need to initialize the necessary parameters for a linear model and define the forward pass for an input x. Hint: It <b>should</b> look very similar to what you have done before.

# %%
class LinearClassifier(nn.Module):
    """Support Vector Machine"""

    def __init__(self, dim):
        super(LinearClassifier, self).__init__()
        self.w = nn.Parameter(torch.randn(dim, 1), requires_grad=True)
        self.b = nn.Parameter(torch.randn(1), requires_grad=True)

    def forward(self, x):
        return x @ self.w + self.b

# %% [markdown]
# Finally, implement <code>primalSVM</code>. This is a method which takes in a set of training data <code>xTr</code> and labels <code>yTr</code>, a number of epochs <code>num_epochs</code> to train for, and our SVM <code>C</code> hyper-parameter. You should return a lambda function (https://www.w3schools.com/python/python_lambda.asp) <code>svmclassify</code> that produces a forward pass of your trained model.

# %%
def primalSVM(xTr, yTr, num_epochs=1000, C=1, lr=1e-2, print_freq=100):
    ndims = xTr.shape[1]
    print(ndims)
    
    svmclassify = LinearClassifier(ndims)  # initialize the model
    optimizer = optim.SGD(svmclassify.parameters(), lr=lr)  # create an SGD optimizer for the model parameters
    
    for epoch in range(num_epochs):
        # need to zero the gradients in the optimizer so we don't
        # use the gradients from previous iterations
        optimizer.zero_grad()  
        pred = svmclassify.forward(xTr)  # compute model predictions
        loss = C* torch.sum(hinge_loss(pred, yTr.view_as(pred))) + (svmclassify.w.T @svmclassify.w)
        loss.backward()  # compute the gradient wrt loss
        optimizer.step()  # performs a step of gradient descent
        if (epoch + 1) % print_freq == 0:
            print('epoch {} loss {}'.format(epoch+1, loss.item()))
    
    return lambda xTe: svmclassify.forward(xTe).flatten()

# %% [markdown]
# We can test your SVM primal solver with the following randomly generated data set. We label it in a way that it is guaranteed to be linearly separable. If your code works correctly the hyper-plane should separate all the $x$'s into the red half and all the $o$'s into the blue half. With sufficiently large values of $C$ (e.g. $C>10$) you should obtain $0\%$ training error.

# %%
xTr,yTr = genrandomdata()
fun = primalSVM(xTr,yTr,C=10)
visclassifier.visclassifier(fun,xTr,yTr)
err=torch.mean((torch.sign(fun(xTr))!=yTr).float())
print("Training error: %2.1f%%" % (err*100))
# Out:
# 2
# epoch 100 loss 68.93553161621094
# epoch 200 loss 65.93302154541016
# epoch 300 loss 61.91314697265625
# epoch 400 loss 63.13595199584961
# epoch 500 loss 62.10076141357422
# epoch 600 loss 62.05877685546875
# epoch 700 loss 62.95995330810547
# epoch 800 loss 65.6715087890625
# epoch 900 loss 71.08723449707031
# epoch 1000 loss 62.759979248046875
# Training error: 0.0%

# %%
# Hidden Test 1: testCase_Primal
# ------------------------------
# Given a fixed training set, this tests if the signs of predictions are correct

# %%
# Hidden Test 2: testCase_Primal
# ------------------------------
# Given a fixed training set, this tests if points farther from the decision boundary have larger predictions.

# %% [markdown]
# <h3>Spiral data set</h3>
#
# <p>The linear classifier works great in simple linear cases. But what if the data is more complicated? We provide you with a "spiral" data set. You can load it and visualize it with the following two code snippets:
# <pre>

# %%
def spiraldata(N=300):
    r = np.linspace(1,2*np.pi,N)
    xTr1 = np.array([np.sin(2.*r)*r, np.cos(2*r)*r]).T
    xTr2 = np.array([np.sin(2.*r+np.pi)*r, np.cos(2*r+np.pi)*r]).T
    xTr = np.concatenate([xTr1, xTr2], axis=0)
    yTr = np.concatenate([np.ones(N), -1 * np.ones(N)])
    xTr = xTr + np.random.randn(xTr.shape[0], xTr.shape[1])*0.2
    
    xTe = xTr[::2,:]
    yTe = yTr[::2]
    xTr = xTr[1::2,:]
    yTr = yTr[1::2]
    
    xTr = torch.tensor(xTr).float()
    yTr = torch.tensor(yTr).float()
    xTe = torch.tensor(xTe).float()
    yTe = torch.tensor(yTe).float()
    
    vals, indices = torch.max(xTr, dim=0, keepdim=True)
    xTr /= (vals * 2.0)
    vals, indices = torch.max(xTe, dim=0, keepdim=True)
    xTe /= (vals * 2.0)
    
    return xTr,yTr,xTe,yTe

# %%
xTr,yTr,xTe,yTe=spiraldata()
plt.figure()
plt.scatter(xTr[yTr == 1, 0], xTr[yTr == 1, 1], c='b')
plt.scatter(xTr[yTr != 1, 0], xTr[yTr != 1, 1], c='r')
plt.legend(["+1","-1"])
plt.show()

# %% [markdown]
# <p>If you apply your previously functioning linear classifier on this data set you will see that you get terrible results. Your training error will increase drastically. </p>

# %%
fun=primalSVM(xTr,yTr,C=10)
visclassifier.visclassifier(fun,xTr,yTr)
err=torch.mean(((torch.sign(fun(xTr)))!=yTr).float())
print("Training error: %2.1f%%" % (err*100))
# Out:
# 2
# epoch 100 loss 11232.591796875
# epoch 200 loss 11232.646484375
# epoch 300 loss 11232.642578125
# epoch 400 loss 11232.630859375
# epoch 500 loss 11232.6171875
# epoch 600 loss 11232.603515625
# epoch 700 loss 11232.5927734375
# epoch 800 loss 11232.578125
# epoch 900 loss 11232.5634765625
# epoch 1000 loss 11232.5517578125
# Training error: 44.3%

# %% [markdown]
# <h3>Implementing a kernelized SVM</h3>
#
# <p> For a data set as complex as the spiral data set, you will need a more complex classifier.
# First implement the kernel function
# <pre>	computeK(kernel_type,X,Z,kpar)</pre>
# It takes as input a kernel type <code>kernel_type</code> and two data sets $\mathbf{X} \in \mathcal{R}^{n\times d}$ and $\mathbf{Z} \in \mathcal{R}^{m\times d}$ and outputs a kernel matrix $\mathbf{K}\in{\mathcal{R}^{n\times m}}$. The last input, <code>kpar</code> specifies the kernel parameter (e.g. the inverse kernel width $\gamma$ in the RBF case or the degree $p$ in the polynomial case.)
# 	<ol>
# 	<li>For the linear kernel (<code>kernel_type='linear'</code>) svm, use $k(\mathbf{x},\mathbf{z})=x^Tz$ </li>
# 	<li>For the radial basis function kernel (<code>kernel_type='rbf'</code>) svm use $k(\mathbf{x},\mathbf{z})=\exp(-\gamma ||x-z||^2)$ (gamma is a hyperparameter, passed as the value of kpar)</li>
# 	<li>For the polynomial kernel (<code>kernel_type='poly'</code>) use  $k(\mathbf{x},\mathbf{z})=(x^Tz + 1)^d$ (d is the degree of the polymial, passed as the value of kpar)</li>
# </ol>
#
# <p>You can use the function <b><code>l2distance</code></b> as a helperfunction, which is located in defined in one of your starter files l2distance.py.</p>

# %%
def computeK(kernel_type, X, Z, kpar=0):
    """
    function K = computeK(kernel_type, X, Z)
    computes a matrix K such that Kij=k(x,z);
    for three different function linear, rbf or polynomial.
    
    Input:
    kernel_type: either 'linear','polynomial','rbf'
    X: n input vectors of dimension d (nxd);
    Z: m input vectors of dimension d (mxd);
    kpar: kernel parameter (inverse kernel width gamma in case of RBF, degree in case of polynomial)
    
    OUTPUT:
    K : nxm kernel Torch float tensor
    """
    assert kernel_type in ["linear","polynomial","poly","rbf"], "Kernel type %s not known." % kernel_type
    assert X.shape[1] == Z.shape[1], "Input dimensions do not match"
    
    if(kernel_type =="linear"):
        K = X.T @ Z
        
    if(kernel_type =="poly" or kernel_type =="polynomial"):
        K = (X.T @ Z +1)**kpar
    
    if(kernel_type =="rbf"):
        K = np.exp(-kpar* l2distance(X,Z)**2)   

    return K

# %%
# Hidden Test 3: testCase_computeK_linear
# ---------------------------------------
# This tests whether the linear kernel is computed properly on an example dataset.

# %%
# Hidden Test 4: testCase_computeK_polynomial
# -------------------------------------------
# This tests whether the polynomial kernel is computed properly on an example dataset.

# %%
# Hidden Test 5: testCase_computeK_rbf
# ------------------------------------
# This tests whether the rbf kernel is computed properly on an example dataset.

# %% [markdown]
# <h3>Additional Testing</h3>
# <p>The following code snippet plots an image of the kernel matrix for the data points in the spiral set. Use it to test your <b><code>computeK</code></b> function:</p>

# %%
xTr,yTr,xTe,yTe=spiraldata()
K=computeK("rbf",xTr,xTr,kpar=0.05)
# plot an image of the kernel matrix
plt.figure()
plt.pcolormesh(K, cmap='jet')
plt.show()

# %% [markdown]
# Remember that the SVM optimization has the following dual formulation: (1)
# $$
# \begin{aligned}
#              &\min_{\alpha_1,\cdots,\alpha_n}\frac{1}{2} \sum_{i,j}\alpha_i \alpha_j y_i y_j \mathbf{K}_{ij} - \sum_{i=1}^{n}\alpha_i  \\
#        \text{s.t.}  &\quad 0 \leq \alpha_i \leq C\\
#              &\quad \sum_{i=1}^{n} \alpha_i y_i = 0.
# \end{aligned}
# $$
# This is equivalent to solving for the SVM primal (2)
# $$ L(\mathbf{w},b) = C\sum_{i=1}^n \max(1-y_i(\mathbf{w}^\top\phi(\mathbf{x}_i)+b),0) + ||w||_2^2$$
# where $\mathbf{w}=\sum_{i=1}^n y_i \alpha_i \phi(\mathbf{x}_i)$ and $\mathbf{K}_{ij}=k(\mathbf{x}_i,\mathbf{x}_j)=\phi(\mathbf{x}_i)^\top\phi(\mathbf{x}_j)$, for some mapping $\phi(\cdot)$. However, after a change of variable, with $\beta_i = \alpha_iy_i$ and $\beta \in R^n$, (2) can be rewritten as follows (see https://arxiv.org/pdf/1404.1066.pdf for details):
# $$ min_{\beta, b} \frac{1}{2}\beta^\top K\beta + \frac{C}{2}\sum_{i=1}^n {[\max(1-y_i(\beta^\top k_i+b),0)]}^2$$
# where $k_i$ is the kernel matrix row corresponding to the ith training example. Notice that there are two relaxations: 1. the $\beta_i$ are unconstrained, in contrast to $\alpha_i$ in (1), which must satisfy $0 \leq \alpha_i \leq C$; and 2. the squared hinge loss is used in place of the more common absolute hinge loss.

# %% [markdown]
# <p>
#     Implement the module
#     <pre>
#     KernelizedSVM(dim, kernel_type, kpar=0)
#     </pre>
#     This is a kernelized version of the SVM as defined above, which must maintain some kind of internal parameters for beta and b (hint: think what <code>dim</code> should be as a function of our training data) should be used for. Further, you are given <code>kernel_type</code> and <code>kpar</code>, which you should use in the creation of kernels by means of the method you wrote above <code>computeK</code>. For the forward pass of the kernelized SVM, recall that it is defined as $h(x) = w^\top \phi(x) + b$, where $w = \sum_{i=1}^n \beta_i\phi(x_i)$. The output of your forward pass should be the classification itself of input data x.
# </p>

# %%
class KernelizedSVM(nn.Module):
    def __init__(self, dim, kernel_type, kpar=0):
        super(KernelizedSVM, self).__init__()
        self.kpar = kpar
        self.kernel_type = kernel_type
        self.b = nn.Parameter(torch.randn(1), requires_grad=True)
        self.alpha = nn.Parameter(torch.randn(dim), requires_grad=True)
        
    def forward(self, xTr, x):
        # if xTr is None:
        #     xTr = x.detach()  # store the training data
        K = computeK(self.kernel_type, xTr, x, self.kpar)

        return torch.sign(K.T@self.alpha + self.b)

# %% [markdown]
# <p>
#     Implement the function
#     <pre>
#     kernelsvm_loss(kernelizedSVM, kernel_mat, yTr, C)
#     </pre>
#     It should implement the loss function described above for the equivalent primal formulation of the dual:
#     $$ min_{\beta, b} \frac{1}{2}\beta^\top K\beta + \frac{C}{2}\sum_{i=1}^n {[\max(1-y_i(\beta^\top k_i+b),0)]}^2$$
#   You are given a KernalizedSVM module (<code>kernelizedSVM</code>) which you defined above, the kernel (<code>kernel_mat</code>), the training labels (<code>yTr</code>), and the regularizatin paramater (<code>C</code>).
#
# Note that this function <b>requires no loops</b>, and that you may find two functions especially helpful
# * <code>F.relu(x)</code> computes the <code>max(x,0)</code> in a way that allows for our optimizers to work (F is torch.nn.Functional, a library imported above)
# * <code>torch.square(x)</code> Returns a new tensor with the square of the elements of input.
# </p>

# %%
def kernelsvm_loss(kernelizedSVM, kernel_mat, yTr, C):
    loss = torch.sum(torch.square(F.relu(1-yTr*(kernelizedSVM.alpha.T@kernel_mat+ kernelizedSVM.b))))
    reg = kernelizedSVM.alpha.T @kernel_mat@ kernelizedSVM.alpha
    cumulative_loss = 1/2*reg +C/2* loss

    return cumulative_loss

# %% [markdown]
# <p>
#     Implement the function
#     <pre>
#     dualSVM(xTr, yTr, kernel_type, num_epochs, C, kpar, lr)
#     </pre>
#     It should use your functions <code><b>kernelsvm_loss</b></code>, <code><b>computeK</b></code>, and <code><b>KernelizedSVM</b></code> to solve the SVM dual problem of an SVM specified by a training data set (<code><b>xTr,yTr</b></code>), a regularization parameter (<code>C</code>), a kernel type (<code>ktype</code>) and kernel parameter (<code>lmbda</code>), to be used as kpar in Kernel construction. This will once again be a training loop similar to the primalSVM above. You should return a lambda function <code>svmclassify</code> that produces a forward pass of your trained model.
# </p>

# %%
def dualSVM(xTr, yTr, kernel_type, num_epochs=100, C=1, lmbda=0, lr=1e-3, print_freq=100):
    ndims = xTr.shape[0]
    
    svmclassify = KernelizedSVM(ndims, kernel_type, lmbda)  # initialize the model
    optimizer = optim.SGD(svmclassify.parameters(), lr=lr)  # create an SGD optimizer for the model parameters
    kernel_matrix = computeK(kernel_type, xTr, xTr, lmbda)
    min_loss = np.inf
    loss_diff_threshold = 1e-2
    
    for epoch in range(num_epochs):
        # need to zero the gradients in the optimizer so we don't
        # use the gradients from previous iterations
        
        #pred = svmclassify.forward(xTr, xTr)  # compute model predictions
        
        loss = kernelsvm_loss(svmclassify, kernel_matrix, yTr, C)
        optimizer.zero_grad()
        loss.backward()  # compute the gradient wrt loss
        optimizer.step()  # performs a step of gradient descent
        if (epoch + 1) % print_freq == 0:
            print('epoch {} loss {}'.format(epoch+1, loss.item()))
        if abs(min_loss - loss.item()) < loss_diff_threshold:
            print('Early stopping due to small loss difference!')
            break
        min_loss = loss.item()
    
    return lambda x: svmclassify.forward(xTr,x).flatten()

# %% [markdown]
# <h3>Testing</h3>
# <p>Now we try the SVM with RBF kernel on the spiral data. If you implemented it correctly, train and test error should be close to zero.</p>

# %%
xTr,yTr,xTe,yTe=spiraldata()

# poly kernel parameters that don't blow up vvv
# ktype="poly"
# svmclassify=dualSVM(xTr, yTr, kernel_type=ktype, num_epochs=10, C=0.1, lmbda=0.05, lr=1e-4)
# visclassifier.visclassifier(svmclassify,xTr,yTr)

# linear kernel parameters that also don't blow up vvv
# ktype="linear"
# svmclassify=dualSVM(xTr, yTr, kernel_type=ktype, num_epochs=10, C=0.1, lmbda=0.05, lr=1e-4)
# visclassifier.visclassifier(svmclassify,xTr,yTr)

# rbf kernel with parameters that achieve perfect accuracy vvv 
ktype="rbf"
svmclassify=dualSVM(xTr, yTr, kernel_type=ktype, num_epochs=1000, C=1, lmbda=100, lr=1e-3)
visclassifier.visclassifier(svmclassify,xTr,yTr)

# compute training and testing error
predsTr=svmclassify(xTr)
trainingerr=torch.mean((torch.sign(predsTr)!=yTr).float())
print("Training error: %2.4f" % trainingerr)

predsTe=svmclassify(xTe)
testingerr=torch.mean((torch.sign(predsTe)!=yTe).float())
print("Testing error: %2.4f" % testingerr)
# Out:
# C:\Users\alina\AppData\Local\Temp\ipykernel_17104\4010647137.py:2: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3618.)
#   loss = torch.sum(torch.square(F.relu(1-yTr*(kernelizedSVM.alpha.T@kernel_mat+ kernelizedSVM.b))))
# epoch 100 loss 71.05949401855469
# epoch 200 loss 48.196990966796875
# epoch 300 loss 39.90975570678711
# epoch 400 loss 36.14441680908203
# epoch 500 loss 34.06782531738281
# epoch 600 loss 32.74223709106445
# Early stopping due to small loss difference!
# Training error: 0.0000
# Testing error: 0.0000

# %% [markdown]
# <h3>Testing Hint</h3> Create a dataset where you know what some of the optimal values of $\alpha$ will be, and test to make sure that the solution gets those values of $\alpha$ correct (recall from the lecture that the $\alpha$ values associated with certain data points are guaranteed to have a specific optimal value).

# %%
# Hidden Test 6: testCase_dualSVM_easy_dataset
# --------------------------------------------
# This tests whether the function from dualSVM correctly classifies an example dataset.

# %%
# Hidden Test 7: testCase_dualSVM_hard_dataset
# --------------------------------------------
# This tests whether the function from dualSVM correctly classifies a hard example dataset.

# %%
# Hidden Test 8: testCase_dualSVM_hard_dataset2
# ---------------------------------------------
# This tests whether the function from dualSVM correctly classifies an even harder example dataset.

# %% [markdown]
# SVMs are pretty sensitive to hyper-parameters. We ask you to implement a cross-validation function. <code>cross_validation</code> which takes training data <code>xTr</code>, training labels <code>yTr</code>, validation data <code>xValid</code>, validation labels <code>yValid</code>, kernel type <code>ktype</code>, list of possible C values <code>CList</code>, list of lambda values for kernel generation <code>lmbdaList</code>, and list of learning rates <code>lr_list</code>.
#
# Note that we don't have <code>epochs</code> as a hyper-parameter to tune even, though the number of epochs we train on can vastly change the performance of our model. Generally we train with gradient descent <b>until convergence</b> (when train/validation loss stop decreasing); therefore, something you can do to get a good idea of what amount of epochs you need is plot [epoch number x (training,validation)] loss! <b>This convergence part will not be tested</b>, but is something that might help.

# %%
def cross_validation(xTr,yTr,xValid,yValid,ktype,CList,lmbdaList,lr_List):
    """
    function bestC,bestLmbda,ErrorMatrix = cross_validation(xTr,yTr,xValid,yValid,ktype,CList,lmbdaList);
    Use the parameter search to find the optimal parameter,
    Individual models are trained on (xTr,yTr) while validated on (xValid,yValid)
    
    Input:
        xTr      | training data (nxd)
        yTr      | training labels (nx1)
        xValid   | training data (mxd)
        yValid   | training labels (mx1)
        ktype    | the type of kernelization: 'rbf','polynomial','linear'
        CList    | The list of values to try for the SVM regularization parameter C (ax1)
        lmbdaList| The list of values to try for the kernel parameter lmbda- degree for poly, inverse width for rbf (bx1)
        lr_list  | The list of values to try for the learning rate of our optimizer
    
    Output:
        bestC      | the best C parameter
        bestLmbda  | the best Lmbda parameter
        bestLr     | the best Lr parameter
        ErrorMatrix| the test error rate for each given (C, Lmbda Lr) tuple when trained on (xTr,yTr) and tested on (xValid,yValid)
    """
    prevTrErr = torch.inf
    bestC = torch.inf
    bestLmbda = torch.inf
    bestLr = torch.inf
    ErrorMatrix = torch.zeros(size=(len(CList), len(lmbdaList), len(lr_List)))
    for i, c in enumerate(CList):
        for j, lmbda in enumerate(lmbdaList):
            for k, lr in enumerate(lr_List):
                svmclassify=dualSVM(xTr, yTr, kernel_type=ktype, num_epochs=700, C=c, lmbda=lmbda, lr=lr)
                #visclassifier.visclassifier(svmclassify,xTr,yTr)

                # compute training and testing error
                #predsTr=svmclassify(xTr)
                #trainingerr=torch.mean((torch.sign(predsTr)!=yTr).float())
                #print("Training error: %2.4f" % trainingerr)
                
                predsTe=svmclassify(xValid)
                testingerr=torch.mean((torch.sign(predsTe)!=yValid).float())
                print("Testing error: %2.4f" % testingerr)
                ErrorMatrix[i, j, k] = testingerr
                
                # if (testingerr<prevTrErr):
                #     bestC = c
                #     bestLmbda = lmbda
                #     bestLr = lr
                #     prevTrErr = testingerr 
    min_error_idx = torch.argmin(ErrorMatrix)  # Get the index of the minimum error
    i, j, k = np.unravel_index(min_error_idx, ErrorMatrix.shape)  # Convert the index to 3D

    bestC = CList[i]
    bestLmbda = lmbdaList[j]
    bestLr = lr_List[k]
                    
    return bestC,bestLmbda,bestLr,ErrorMatrix

# %% [markdown]
# <h3>Testing</h3>

# %%
xTr,yTr,xValid,yValid=spiraldata(100)
CList=(2.0**np.linspace(-2,3,6))
lmbdaList=np.linspace(50, 100, 8)
lrList=(np.linspace(0.001,0.005,5))

bestC,bestLmbda,bestLr,ErrorMatrix = cross_validation(xTr,yTr,xValid,yValid,'rbf',CList,lmbdaList,lrList)
print(bestC)
print(bestLmbda)
print(bestLr)
print(ErrorMatrix)
# Out:
# epoch 100 loss 52.83036804199219
# epoch 200 loss 34.22441864013672
# epoch 300 loss 25.503719329833984
# epoch 400 loss 20.761484146118164
# epoch 500 loss 17.93428611755371
# epoch 600 loss 16.10647201538086
# epoch 700 loss 14.84682846069336
# Testing error: 0.2800
# epoch 100 loss 25.876548767089844
# epoch 200 loss 18.678394317626953
# epoch 300 loss 15.406501770019531
# epoch 400 loss 13.607466697692871
# Early stopping due to small loss difference!
# Testing error: 0.2500
# epoch 100 loss 18.520492553710938
# epoch 200 loss 13.18193244934082
# epoch 300 loss 11.488210678100586
# Early stopping due to small loss difference!
# Testing error: 0.1300
# epoch 100 loss 14.237478256225586
# epoch 200 loss 11.318571090698242
# Early stopping due to small loss difference!
# Testing error: 0.0700
# epoch 100 loss 15.377296447753906
# epoch 200 loss 11.700830459594727
# Early stopping due to small loss difference!
# Testing error: 0.1100
# epoch 100 loss 44.68033981323242
# epoch 200 loss 29.187837600708008
# epoch 300 loss 22.623088836669922
# epoch 400 loss 18.96059226989746
# epoch 500 loss 16.67148208618164
# epoch 600 loss 15.138022422790527
# Early stopping due to small loss difference!
# Testing error: 0.1700
# epoch 100 loss 30.98946762084961
# epoch 200 loss 19.51508331298828
# epoch 300 loss 15.964946746826172
# epoch 400 loss 14.132196426391602
# Early stopping due to small loss difference!
# Testing error: 0.1100
# epoch 100 loss 20.781604766845703
# epoch 200 loss 14.37613296508789
# epoch 300 loss 12.308343887329102
# Early stopping due to small loss difference!
# Testing error: 0.1400
# epoch 100 loss 14.292060852050781
# epoch 200 loss 11.733595848083496
# Early stopping due to small loss difference!
# Testing error: 0.0900
# epoch 100 loss 14.26158332824707
# epoch 200 loss 11.261725425720215
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 48.627891540527344
# epoch 200 loss 30.346088409423828
# epoch 300 loss 22.312585830688477
# epoch 400 loss 18.298498153686523
# epoch 500 loss 16.055700302124023
# epoch 600 loss 14.644732475280762
# Early stopping due to small loss difference!
# Testing error: 0.1400
# epoch 100 loss 27.85902214050293
# epoch 200 loss 18.288135528564453
# epoch 300 loss 14.742561340332031
# epoch 400 loss 13.003927230834961
# Early stopping due to small loss difference!
# Testing error: 0.1900
# epoch 100 loss 19.070575714111328
# epoch 200 loss 13.809703826904297
# epoch 300 loss 11.873176574707031
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 18.198383331298828
# epoch 200 loss 12.641639709472656
# Early stopping due to small loss difference!
# Testing error: 0.0900
# epoch 100 loss 14.673656463623047
# epoch 200 loss 11.499624252319336
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 36.78597640991211
# epoch 200 loss 25.298555374145508
# epoch 300 loss 19.612279891967773
# epoch 400 loss 16.255329132080078
# epoch 500 loss 14.161798477172852
# epoch 600 loss 12.807304382324219
# Early stopping due to small loss difference!
# Testing error: 0.2200
# epoch 100 loss 36.26494598388672
# epoch 200 loss 22.007076263427734
# epoch 300 loss 16.211803436279297
# epoch 400 loss 13.459097862243652
# epoch 500 loss 12.018662452697754
# Early stopping due to small loss difference!
# Testing error: 0.1400
# epoch 100 loss 26.119537353515625
# epoch 200 loss 16.906932830810547
# epoch 300 loss 13.707758903503418
# epoch 400 loss 12.187132835388184
# Early stopping due to small loss difference!
# Testing error: 0.0900
# epoch 100 loss 15.703168869018555
# epoch 200 loss 11.460664749145508
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 15.854925155639648
# epoch 200 loss 11.774330139160156
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 44.628211975097656
# epoch 200 loss 31.537643432617188
# epoch 300 loss 24.679340362548828
# epoch 400 loss 20.646276473999023
# epoch 500 loss 18.07498550415039
# epoch 600 loss 16.317752838134766
# epoch 700 loss 15.060669898986816
# Testing error: 0.1400
# epoch 100 loss 32.997337341308594
# epoch 200 loss 21.767131805419922
# epoch 300 loss 17.23025894165039
# epoch 400 loss 14.763961791992188
# epoch 500 loss 13.21791934967041
# Early stopping due to small loss difference!
# Testing error: 0.1400
# epoch 100 loss 23.864463806152344
# epoch 200 loss 15.74992561340332
# epoch 300 loss 12.861576080322266
# Early stopping due to small loss difference!
# Testing error: 0.1000
# epoch 100 loss 19.19482421875
# epoch 200 loss 12.733739852905273
# epoch 300 loss 10.8353271484375
# Early stopping due to small loss difference!
# Testing error: 0.1300
# epoch 100 loss 16.349781036376953
# epoch 200 loss 11.73628044128418
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 48.04039001464844
# epoch 200 loss 32.63394546508789
# epoch 300 loss 25.08376693725586
# epoch 400 loss 20.749523162841797
# epoch 500 loss 18.052978515625
# epoch 600 loss 16.250837326049805
# epoch 700 loss 14.970348358154297
# Testing error: 0.1900
# epoch 100 loss 25.40184783935547
# epoch 200 loss 15.926356315612793
# epoch 300 loss 12.53494644165039
# Early stopping due to small loss difference!
# Testing error: 0.0600
# epoch 100 loss 22.090194702148438
# epoch 200 loss 14.607163429260254
# epoch 300 loss 12.083866119384766
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 18.006969451904297
# epoch 200 loss 12.386478424072266
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 16.222623825073242
# epoch 200 loss 12.110295295715332
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 39.32604217529297
# epoch 200 loss 29.283679962158203
# epoch 300 loss 23.510936737060547
# epoch 400 loss 19.709224700927734
# epoch 500 loss 17.0784969329834
# epoch 600 loss 15.197972297668457
# epoch 700 loss 13.81809139251709
# Testing error: 0.2000
# epoch 100 loss 29.712650299072266
# epoch 200 loss 19.161781311035156
# epoch 300 loss 15.118941307067871
# epoch 400 loss 13.050338745117188
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 21.83284568786621
# epoch 200 loss 14.24159049987793
# epoch 300 loss 11.966280937194824
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 24.394819259643555
# epoch 200 loss 15.967636108398438
# epoch 300 loss 13.011625289916992
# epoch 400 loss 11.597223281860352
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 15.576369285583496
# epoch 200 loss 11.484090805053711
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 49.3505859375
# epoch 200 loss 36.14945983886719
# epoch 300 loss 28.12937355041504
# epoch 400 loss 22.99343490600586
# epoch 500 loss 19.568645477294922
# epoch 600 loss 17.22205352783203
# epoch 700 loss 15.553829193115234
# Testing error: 0.1500
# epoch 100 loss 28.449718475341797
# epoch 200 loss 18.914161682128906
# epoch 300 loss 14.930337905883789
# epoch 400 loss 12.952095985412598
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 20.97081756591797
# epoch 200 loss 14.20355224609375
# epoch 300 loss 12.009415626525879
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 22.490734100341797
# epoch 200 loss 14.268799781799316
# epoch 300 loss 11.711280822753906
# Early stopping due to small loss difference!
# Testing error: 0.0400
# epoch 100 loss 14.944393157958984
# epoch 200 loss 11.277135848999023
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 37.68271255493164
# epoch 200 loss 29.116065979003906
# epoch 300 loss 25.597211837768555
# epoch 400 loss 23.507293701171875
# epoch 500 loss 22.059505462646484
# Early stopping due to small loss difference!
# Testing error: 0.1400
# epoch 100 loss 35.393489837646484
# epoch 200 loss 23.433780670166016
# epoch 300 loss 19.915752410888672
# Early stopping due to small loss difference!
# Testing error: 0.1000
# epoch 100 loss 25.271657943725586
# epoch 200 loss 19.455411911010742
# epoch 300 loss 17.735107421875
# Early stopping due to small loss difference!
# Testing error: 0.0400
# epoch 100 loss 24.245399475097656
# epoch 200 loss 19.101503372192383
# Early stopping due to small loss difference!
# Testing error: 0.0400
# epoch 100 loss 21.22296905517578
# epoch 200 loss 17.186031341552734
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 46.24412536621094
# epoch 200 loss 31.278419494628906
# epoch 300 loss 25.201871871948242
# epoch 400 loss 22.204490661621094
# epoch 500 loss 20.437015533447266
# Early stopping due to small loss difference!
# Testing error: 0.0800
# epoch 100 loss 25.593278884887695
# epoch 200 loss 20.566810607910156
# epoch 300 loss 18.690536499023438
# Early stopping due to small loss difference!
# Testing error: 0.1000
# epoch 100 loss 32.07078170776367
# epoch 200 loss 21.55199432373047
# epoch 300 loss 18.431812286376953
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 25.242366790771484
# epoch 200 loss 18.370468139648438
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 20.922210693359375
# epoch 200 loss 17.286865234375
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 42.18363952636719
# epoch 200 loss 29.77348518371582
# epoch 300 loss 24.133127212524414
# epoch 400 loss 21.11501693725586
# epoch 500 loss 19.34528350830078
# Early stopping due to small loss difference!
# Testing error: 0.1200
# epoch 100 loss 37.305328369140625
# epoch 200 loss 23.900541305541992
# epoch 300 loss 19.943523406982422
# epoch 400 loss 18.082660675048828
# Early stopping due to small loss difference!
# Testing error: 0.0400
# epoch 100 loss 24.25670623779297
# epoch 200 loss 18.823471069335938
# epoch 300 loss 16.842445373535156
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 24.079059600830078
# epoch 200 loss 18.375518798828125
# epoch 300 loss 16.554576873779297
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 18.875751495361328
# epoch 200 loss 16.17343521118164
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 64.697265625
# epoch 200 loss 41.289161682128906
# epoch 300 loss 30.882814407348633
# epoch 400 loss 25.344532012939453
# epoch 500 loss 22.045665740966797
# epoch 600 loss 19.922882080078125
# epoch 700 loss 18.478195190429688
# Testing error: 0.0600
# epoch 100 loss 28.55725860595703
# epoch 200 loss 20.460493087768555
# epoch 300 loss 17.59880828857422
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 26.84323501586914
# epoch 200 loss 19.035541534423828
# epoch 300 loss 16.586122512817383
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 19.937576293945312
# epoch 200 loss 15.864891052246094
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 23.15414810180664
# epoch 200 loss 17.527477264404297
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 47.02608108520508
# epoch 200 loss 33.37432861328125
# epoch 300 loss 26.685522079467773
# epoch 400 loss 22.934757232666016
# epoch 500 loss 20.595441818237305
# epoch 600 loss 19.012020111083984
# Early stopping due to small loss difference!
# Testing error: 0.0700
# epoch 100 loss 39.18231964111328
# epoch 200 loss 24.320171356201172
# epoch 300 loss 19.313692092895508
# epoch 400 loss 17.11842918395996
# Early stopping due to small loss difference!
# Testing error: 0.0400
# epoch 100 loss 28.77817726135254
# epoch 200 loss 20.184009552001953
# epoch 300 loss 17.355609893798828
# Early stopping due to small loss difference!
# Testing error: 0.0400
# epoch 100 loss 24.901973724365234
# epoch 200 loss 18.558494567871094
# epoch 300 loss 16.45994758605957
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 19.890762329101562
# epoch 200 loss 16.045747756958008
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 42.98651123046875
# epoch 200 loss 29.122520446777344
# epoch 300 loss 23.148008346557617
# epoch 400 loss 20.080337524414062
# epoch 500 loss 18.350704193115234
# Early stopping due to small loss difference!
# Testing error: 0.0600
# epoch 100 loss 34.32444763183594
# epoch 200 loss 24.49687957763672
# epoch 300 loss 20.32027816772461
# epoch 400 loss 18.073890686035156
# epoch 500 loss 16.706695556640625
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 28.17770767211914
# epoch 200 loss 19.543865203857422
# epoch 300 loss 16.78449249267578
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 22.99155044555664
# epoch 200 loss 17.39211082458496
# epoch 300 loss 15.571966171264648
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 20.673648834228516
# epoch 200 loss 15.645814895629883
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 69.935546875
# epoch 200 loss 45.929595947265625
# epoch 300 loss 34.97883605957031
# epoch 400 loss 28.60479736328125
# epoch 500 loss 24.50149154663086
# epoch 600 loss 21.71664810180664
# epoch 700 loss 19.759294509887695
# Testing error: 0.1700
# epoch 100 loss 34.24965286254883
# epoch 200 loss 23.963733673095703
# epoch 300 loss 19.908531188964844
# epoch 400 loss 17.835094451904297
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 27.97610855102539
# epoch 200 loss 18.87295913696289
# epoch 300 loss 16.13062286376953
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 26.096221923828125
# epoch 200 loss 18.600812911987305
# epoch 300 loss 16.144458770751953
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 21.88531494140625
# epoch 200 loss 16.684091567993164
# epoch 300 loss 14.972509384155273
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 63.035972595214844
# epoch 200 loss 41.182289123535156
# epoch 300 loss 30.71090316772461
# epoch 400 loss 25.073213577270508
# epoch 500 loss 21.76506805419922
# epoch 600 loss 19.70862579345703
# epoch 700 loss 18.350387573242188
# Testing error: 0.0700
# epoch 100 loss 36.825660705566406
# epoch 200 loss 23.235126495361328
# epoch 300 loss 18.54199981689453
# epoch 400 loss 16.4658203125
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 28.487960815429688
# epoch 200 loss 19.440412521362305
# epoch 300 loss 16.745975494384766
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 29.709068298339844
# epoch 200 loss 18.731029510498047
# epoch 300 loss 15.688820838928223
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 21.65924835205078
# epoch 200 loss 16.081212997436523
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 54.814666748046875
# epoch 200 loss 40.459373474121094
# epoch 300 loss 34.8781852722168
# epoch 400 loss 31.517541885375977
# epoch 500 loss 29.293432235717773
# epoch 600 loss 27.760419845581055
# Early stopping due to small loss difference!
# Testing error: 0.0700
# epoch 100 loss 39.17812728881836
# epoch 200 loss 29.07830810546875
# epoch 300 loss 26.116291046142578
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 30.226673126220703
# epoch 200 loss 26.472381591796875
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 30.301633834838867
# epoch 200 loss 25.189403533935547
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 31.95621109008789
# epoch 200 loss 25.288246154785156
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 52.97962951660156
# epoch 200 loss 35.42455291748047
# epoch 300 loss 29.41018295288086
# epoch 400 loss 26.899168014526367
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 41.633033752441406
# epoch 200 loss 30.38251495361328
# epoch 300 loss 26.44228744506836
# epoch 400 loss 24.494117736816406
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 34.573490142822266
# epoch 200 loss 24.794830322265625
# epoch 300 loss 22.5831298828125
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 30.532947540283203
# epoch 200 loss 24.304922103881836
# epoch 300 loss 22.63165283203125
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 28.157272338867188
# epoch 200 loss 23.90830421447754
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 58.302337646484375
# epoch 200 loss 41.0884895324707
# epoch 300 loss 33.62788391113281
# epoch 400 loss 29.623497009277344
# epoch 500 loss 27.183387756347656
# epoch 600 loss 25.57903480529785
# Early stopping due to small loss difference!
# Testing error: 0.0500
# epoch 100 loss 34.13770294189453
# epoch 200 loss 25.439098358154297
# epoch 300 loss 22.68254280090332
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 30.892215728759766
# epoch 200 loss 23.158344268798828
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 24.36505699157715
# epoch 200 loss 21.929290771484375
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 26.84521484375
# epoch 200 loss 22.78844451904297
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 58.164608001708984
# epoch 200 loss 36.875823974609375
# epoch 300 loss 29.18128204345703
# epoch 400 loss 25.695411682128906
# epoch 500 loss 23.850337982177734
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 41.30414581298828
# epoch 200 loss 28.43320083618164
# epoch 300 loss 24.590328216552734
# epoch 400 loss 22.91226577758789
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 33.745201110839844
# epoch 200 loss 25.592269897460938
# epoch 300 loss 23.333648681640625
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 29.751535415649414
# epoch 200 loss 22.862503051757812
# epoch 300 loss 21.137046813964844
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 28.09442138671875
# epoch 200 loss 22.591346740722656
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 70.73570251464844
# epoch 200 loss 45.567508697509766
# epoch 300 loss 34.92726135253906
# epoch 400 loss 29.568161010742188
# epoch 500 loss 26.49858283996582
# epoch 600 loss 24.579139709472656
# epoch 700 loss 23.2896728515625
# Testing error: 0.0300
# epoch 100 loss 45.891754150390625
# epoch 200 loss 30.052326202392578
# epoch 300 loss 25.130769729614258
# epoch 400 loss 23.006973266601562
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 32.94325637817383
# epoch 200 loss 23.594341278076172
# epoch 300 loss 21.30828094482422
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 29.22106170654297
# epoch 200 loss 22.15838623046875
# epoch 300 loss 20.35582733154297
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 25.268138885498047
# epoch 200 loss 21.13320541381836
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 74.51118469238281
# epoch 200 loss 47.61357498168945
# epoch 300 loss 36.53748321533203
# epoch 400 loss 30.775745391845703
# epoch 500 loss 27.39067840576172
# epoch 600 loss 25.205204010009766
# epoch 700 loss 23.714000701904297
# Testing error: 0.0100
# epoch 100 loss 43.42387008666992
# epoch 200 loss 29.17202377319336
# epoch 300 loss 24.8992862701416
# epoch 400 loss 22.880176544189453
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 31.155792236328125
# epoch 200 loss 23.493099212646484
# epoch 300 loss 21.417665481567383
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 29.349288940429688
# epoch 200 loss 22.840351104736328
# epoch 300 loss 21.078645706176758
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 27.847105026245117
# epoch 200 loss 21.55606460571289
# epoch 300 loss 19.84136962890625
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 75.85391235351562
# epoch 200 loss 46.63852310180664
# epoch 300 loss 35.35010528564453
# epoch 400 loss 29.75045394897461
# epoch 500 loss 26.52273941040039
# epoch 600 loss 24.472795486450195
# epoch 700 loss 23.082393646240234
# Testing error: 0.0200
# epoch 100 loss 46.42934799194336
# epoch 200 loss 32.43208694458008
# epoch 300 loss 27.011981964111328
# epoch 400 loss 24.096378326416016
# epoch 500 loss 22.27723503112793
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 34.67894744873047
# epoch 200 loss 23.71014404296875
# epoch 300 loss 21.103713989257812
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 28.130950927734375
# epoch 200 loss 21.023611068725586
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 26.207075119018555
# epoch 200 loss 20.00855255126953
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 75.04164123535156
# epoch 200 loss 47.71177673339844
# epoch 300 loss 37.192649841308594
# epoch 400 loss 31.44589614868164
# epoch 500 loss 27.82208824157715
# epoch 600 loss 25.398393630981445
# epoch 700 loss 23.705398559570312
# Testing error: 0.0200
# epoch 100 loss 39.734413146972656
# epoch 200 loss 27.86178207397461
# epoch 300 loss 23.388816833496094
# epoch 400 loss 21.254669189453125
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 32.6829833984375
# epoch 200 loss 22.45193862915039
# epoch 300 loss 20.21074104309082
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 24.1243896484375
# epoch 200 loss 20.383739471435547
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 25.758974075317383
# epoch 200 loss 20.716205596923828
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 78.82705688476562
# epoch 200 loss 50.873680114746094
# epoch 300 loss 41.459896087646484
# epoch 400 loss 37.28852462768555
# epoch 500 loss 35.03561782836914
# epoch 600 loss 33.663055419921875
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 53.532630920410156
# epoch 200 loss 38.44825744628906
# epoch 300 loss 34.237876892089844
# epoch 400 loss 32.58165740966797
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 43.456260681152344
# epoch 200 loss 35.45629119873047
# epoch 300 loss 32.93663787841797
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 39.04485321044922
# epoch 200 loss 32.70090866088867
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 35.019256591796875
# epoch 200 loss 31.39259147644043
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 58.617862701416016
# epoch 200 loss 43.115272521972656
# epoch 300 loss 37.03809356689453
# epoch 400 loss 34.069480895996094
# epoch 500 loss 32.34564971923828
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 60.577640533447266
# epoch 200 loss 39.58320999145508
# epoch 300 loss 33.511810302734375
# epoch 400 loss 31.132713317871094
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 39.70203399658203
# epoch 200 loss 31.723329544067383
# epoch 300 loss 29.730167388916016
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 33.92863464355469
# epoch 200 loss 30.235734939575195
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 36.49945068359375
# epoch 200 loss 30.962444305419922
# epoch 300 loss 29.019861221313477
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 75.81169128417969
# epoch 200 loss 47.458797454833984
# epoch 300 loss 37.92658233642578
# epoch 400 loss 33.38422393798828
# epoch 500 loss 30.852373123168945
# epoch 600 loss 29.30598258972168
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 52.675567626953125
# epoch 200 loss 36.53460693359375
# epoch 300 loss 31.722827911376953
# epoch 400 loss 29.602359771728516
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 32.80232238769531
# epoch 200 loss 28.09612274169922
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 34.40875244140625
# epoch 200 loss 27.840187072753906
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 30.50631332397461
# epoch 200 loss 27.298858642578125
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 75.01500701904297
# epoch 200 loss 45.21072769165039
# epoch 300 loss 36.42915725708008
# epoch 400 loss 32.872989654541016
# epoch 500 loss 31.005596160888672
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 48.56367492675781
# epoch 200 loss 34.050933837890625
# epoch 300 loss 29.766677856445312
# epoch 400 loss 27.70555877685547
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 41.05071258544922
# epoch 200 loss 29.910053253173828
# epoch 300 loss 26.999645233154297
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 31.6041202545166
# epoch 200 loss 26.871707916259766
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 31.650829315185547
# epoch 200 loss 26.328332901000977
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 77.49102020263672
# epoch 200 loss 45.36481857299805
# epoch 300 loss 35.88199996948242
# epoch 400 loss 31.288455963134766
# epoch 500 loss 28.686172485351562
# epoch 600 loss 27.225372314453125
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 47.891685485839844
# epoch 200 loss 36.000465393066406
# epoch 300 loss 31.25198745727539
# epoch 400 loss 28.558168411254883
# epoch 500 loss 26.874074935913086
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 42.321372985839844
# epoch 200 loss 31.59897804260254
# epoch 300 loss 27.982988357543945
# epoch 400 loss 26.256128311157227
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 30.832399368286133
# epoch 200 loss 26.660076141357422
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 29.91668701171875
# epoch 200 loss 25.659154891967773
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 75.69149017333984
# epoch 200 loss 42.54216766357422
# epoch 300 loss 33.208702087402344
# epoch 400 loss 29.510812759399414
# epoch 500 loss 27.60788345336914
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 36.025787353515625
# epoch 200 loss 28.329851150512695
# epoch 300 loss 26.079097747802734
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 34.850276947021484
# epoch 200 loss 27.134479522705078
# epoch 300 loss 25.207042694091797
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 29.178913116455078
# epoch 200 loss 25.034608840942383
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 29.31521987915039
# epoch 200 loss 25.15209197998047
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 83.63575744628906
# epoch 200 loss 50.808494567871094
# epoch 300 loss 39.41899871826172
# epoch 400 loss 34.113006591796875
# epoch 500 loss 31.041410446166992
# epoch 600 loss 29.01107406616211
# epoch 700 loss 27.5570068359375
# Testing error: 0.0000
# epoch 100 loss 42.602012634277344
# epoch 200 loss 29.674850463867188
# epoch 300 loss 26.232189178466797
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 35.606109619140625
# epoch 200 loss 26.698558807373047
# epoch 300 loss 24.23172378540039
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 36.23386764526367
# epoch 200 loss 28.429737091064453
# epoch 300 loss 25.595523834228516
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 29.404747009277344
# epoch 200 loss 24.84886932373047
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 86.7117691040039
# epoch 200 loss 50.06902313232422
# epoch 300 loss 37.904457092285156
# epoch 400 loss 32.18069076538086
# epoch 500 loss 29.049928665161133
# epoch 600 loss 27.1746768951416
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 40.72608947753906
# epoch 200 loss 31.09913444519043
# epoch 300 loss 27.625324249267578
# epoch 400 loss 25.97084617614746
# Early stopping due to small loss difference!
# Testing error: 0.0200
# epoch 100 loss 35.49083709716797
# epoch 200 loss 28.809967041015625
# epoch 300 loss 26.68094253540039
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 33.10710906982422
# epoch 200 loss 25.4912052154541
# epoch 300 loss 23.43450927734375
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 26.236780166625977
# epoch 200 loss 23.66653060913086
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 113.37095642089844
# epoch 200 loss 66.38973236083984
# epoch 300 loss 51.87858963012695
# epoch 400 loss 45.77366638183594
# epoch 500 loss 42.753395080566406
# epoch 600 loss 41.08787155151367
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 56.59479904174805
# epoch 200 loss 44.89820861816406
# epoch 300 loss 41.567752838134766
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 47.9212646484375
# epoch 200 loss 39.45172119140625
# Early stopping due to small loss difference!
# Testing error: 0.0000
# Early stopping due to small loss difference!
# Testing error: 0.0400
# Early stopping due to small loss difference!
# Testing error: 0.0600
# epoch 100 loss 78.78244018554688
# epoch 200 loss 51.69961166381836
# epoch 300 loss 43.77482604980469
# epoch 400 loss 40.461669921875
# epoch 500 loss 38.725650787353516
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 59.680274963378906
# epoch 200 loss 44.32469177246094
# epoch 300 loss 40.553836822509766
# epoch 400 loss 38.77827072143555
# epoch 500 loss 37.59759521484375
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 46.06413269042969
# epoch 200 loss 38.15174102783203
# epoch 300 loss 35.763240814208984
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 41.18792724609375
# epoch 200 loss 36.409427642822266
# epoch 300 loss 34.99848937988281
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 43.5980224609375
# epoch 200 loss 41.385738372802734
# epoch 300 loss 41.05415344238281
# epoch 400 loss 40.88825225830078
# epoch 500 loss 40.773372650146484
# epoch 600 loss 40.69348907470703
# epoch 700 loss 40.6378173828125
# Testing error: 0.0100
# epoch 100 loss 71.22309875488281
# epoch 200 loss 49.56627655029297
# epoch 300 loss 42.98631286621094
# epoch 400 loss 39.76551818847656
# epoch 500 loss 37.72203826904297
# epoch 600 loss 36.257266998291016
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 52.49243927001953
# epoch 200 loss 38.191932678222656
# epoch 300 loss 35.13447952270508
# epoch 400 loss 33.69541931152344
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 42.82034683227539
# epoch 200 loss 35.79405975341797
# epoch 300 loss 33.43585968017578
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 36.65686798095703
# epoch 200 loss 32.498207092285156
# Early stopping due to small loss difference!
# Testing error: 0.0000
# Early stopping due to small loss difference!
# Testing error: 0.0300
# epoch 100 loss 75.94300842285156
# epoch 200 loss 45.141578674316406
# epoch 300 loss 37.92489242553711
# epoch 400 loss 35.0341796875
# epoch 500 loss 33.456172943115234
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 45.015010833740234
# epoch 200 loss 36.68140411376953
# epoch 300 loss 34.33287811279297
# epoch 400 loss 32.98420715332031
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 36.394805908203125
# epoch 200 loss 32.23079299926758
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 32.48435592651367
# epoch 200 loss 30.173810958862305
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 34.85838317871094
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 67.16612243652344
# epoch 200 loss 44.57408142089844
# epoch 300 loss 38.43706512451172
# epoch 400 loss 35.562355041503906
# epoch 500 loss 33.83743667602539
# epoch 600 loss 32.66145324707031
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 45.64044189453125
# epoch 200 loss 36.6268310546875
# epoch 300 loss 32.883567810058594
# epoch 400 loss 30.925779342651367
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 35.59893798828125
# epoch 200 loss 31.087800979614258
# epoch 300 loss 29.65785789489746
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 35.973609924316406
# epoch 200 loss 30.344879150390625
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 33.53985595703125
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 80.94976043701172
# epoch 200 loss 47.67704391479492
# epoch 300 loss 38.72456359863281
# epoch 400 loss 34.62929916381836
# epoch 500 loss 32.225704193115234
# epoch 600 loss 30.67017936706543
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 41.61183166503906
# epoch 200 loss 33.4876594543457
# epoch 300 loss 30.790868759155273
# epoch 400 loss 29.424875259399414
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 30.904891967773438
# epoch 200 loss 28.296756744384766
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 33.65081787109375
# epoch 200 loss 29.106224060058594
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 33.95952224731445
# epoch 200 loss 29.662540435791016
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 90.62226867675781
# epoch 200 loss 57.83793258666992
# epoch 300 loss 46.583229064941406
# epoch 400 loss 40.24997329711914
# epoch 500 loss 36.075721740722656
# epoch 600 loss 33.19835662841797
# epoch 700 loss 31.236345291137695
# Testing error: 0.0000
# epoch 100 loss 49.882545471191406
# epoch 200 loss 34.76018524169922
# epoch 300 loss 30.347578048706055
# epoch 400 loss 28.609638214111328
# Early stopping due to small loss difference!
# Testing error: 0.0100
# epoch 100 loss 34.83854675292969
# epoch 200 loss 28.495044708251953
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 37.11793518066406
# epoch 200 loss 30.559104919433594
# epoch 300 loss 28.442934036254883
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 31.258502960205078
# epoch 200 loss 28.32164764404297
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 75.42347717285156
# epoch 200 loss 43.84356689453125
# epoch 300 loss 36.10801315307617
# epoch 400 loss 32.933204650878906
# epoch 500 loss 31.137439727783203
# epoch 600 loss 29.940479278564453
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 39.82714080810547
# epoch 200 loss 31.94281005859375
# epoch 300 loss 29.3565616607666
# epoch 400 loss 27.924413681030273
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 41.48334503173828
# epoch 200 loss 32.568824768066406
# epoch 300 loss 29.60503578186035
# epoch 400 loss 28.071619033813477
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 33.495609283447266
# epoch 200 loss 28.681962966918945
# epoch 300 loss 26.79278564453125
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 32.89569091796875
# epoch 200 loss 27.62398910522461
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 94.3207015991211
# epoch 200 loss 58.654022216796875
# epoch 300 loss 50.275333404541016
# epoch 400 loss 47.28929138183594
# epoch 500 loss 45.90473175048828
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 61.173736572265625
# epoch 200 loss 47.56426239013672
# epoch 300 loss 45.21501159667969
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 63.24640655517578
# epoch 200 loss 55.169227600097656
# epoch 300 loss 53.99372100830078
# epoch 400 loss 53.242374420166016
# epoch 500 loss 52.93037033081055
# epoch 600 loss 52.69268798828125
# epoch 700 loss 52.497188568115234
# Testing error: 0.0100
# epoch 100 loss inf
# epoch 200 loss nan
# epoch 300 loss nan
# epoch 400 loss nan
# epoch 500 loss nan
# epoch 600 loss nan
# epoch 700 loss nan
# Testing error: 1.0000
# epoch 100 loss nan
# epoch 200 loss nan
# epoch 300 loss nan
# epoch 400 loss nan
# epoch 500 loss nan
# epoch 600 loss nan
# epoch 700 loss nan
# Testing error: 1.0000
# epoch 100 loss 91.92705535888672
# epoch 200 loss 56.33506774902344
# epoch 300 loss 48.57524108886719
# epoch 400 loss 45.625221252441406
# epoch 500 loss 43.96895217895508
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 50.12682342529297
# epoch 200 loss 42.53634262084961
# epoch 300 loss 40.587005615234375
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 47.307838439941406
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 1027.5509033203125
# epoch 200 loss 285.3533935546875
# epoch 300 loss 93.94596862792969
# epoch 400 loss 44.811126708984375
# epoch 500 loss 41.086181640625
# epoch 600 loss 52.36558532714844
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss nan
# epoch 200 loss nan
# epoch 300 loss nan
# epoch 400 loss nan
# epoch 500 loss nan
# epoch 600 loss nan
# epoch 700 loss nan
# Testing error: 1.0000
# epoch 100 loss 81.41695404052734
# epoch 200 loss 48.48938751220703
# epoch 300 loss 41.91022872924805
# epoch 400 loss 39.484031677246094
# epoch 500 loss 38.19994354248047
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 49.037662506103516
# epoch 200 loss 39.88249588012695
# epoch 300 loss 37.253807067871094
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 43.022010803222656
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 106.27145385742188
# epoch 200 loss 41.90049743652344
# epoch 300 loss 42.621734619140625
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 1.1012847049066946e+34
# epoch 200 loss nan
# epoch 300 loss nan
# epoch 400 loss nan
# epoch 500 loss nan
# epoch 600 loss nan
# epoch 700 loss nan
# Testing error: 1.0000
# epoch 100 loss 53.42841339111328
# epoch 200 loss 38.63711929321289
# epoch 300 loss 36.105430603027344
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 42.81665802001953
# epoch 200 loss 36.63658142089844
# epoch 300 loss 34.50042724609375
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 41.960758209228516
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 50.469993591308594
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 3552.80615234375
# epoch 200 loss 643.0143432617188
# epoch 300 loss 143.6750946044922
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 57.942867279052734
# epoch 200 loss 42.19866943359375
# epoch 300 loss 38.98772430419922
# epoch 400 loss 37.37265396118164
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 45.88953399658203
# epoch 200 loss 37.818145751953125
# epoch 300 loss 34.57685852050781
# epoch 400 loss 32.63687515258789
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 40.03462219238281
# epoch 200 loss 34.99341583251953
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 39.4290657043457
# epoch 200 loss 37.609642028808594
# epoch 300 loss 36.59823989868164
# epoch 400 loss 36.15445327758789
# epoch 500 loss 35.91157531738281
# epoch 600 loss 35.73588943481445
# epoch 700 loss 35.59721374511719
# Testing error: 0.0000
# epoch 100 loss 610.5625610351562
# epoch 200 loss 109.48651885986328
# epoch 300 loss 44.689247131347656
# epoch 400 loss 68.53135681152344
# epoch 500 loss 31.826082229614258
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 59.60986328125
# epoch 200 loss 41.915489196777344
# epoch 300 loss 37.694766998291016
# epoch 400 loss 35.54484939575195
# epoch 500 loss 34.14283752441406
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 44.916568756103516
# epoch 200 loss 37.34487533569336
# epoch 300 loss 34.000755310058594
# epoch 400 loss 32.262840270996094
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 39.01622009277344
# epoch 200 loss 33.433929443359375
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 40.86507797241211
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 49.986331939697266
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 60.29622268676758
# epoch 200 loss 42.29283905029297
# epoch 300 loss 37.66210174560547
# epoch 400 loss 35.445655822753906
# epoch 500 loss 34.05887985229492
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 39.82080078125
# epoch 200 loss 34.393959045410156
# epoch 300 loss 32.0687255859375
# epoch 400 loss 30.635107040405273
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 42.043739318847656
# epoch 200 loss 35.192726135253906
# epoch 300 loss 32.481014251708984
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 36.899078369140625
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 80.35888671875
# epoch 200 loss 48.88916778564453
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 59.769954681396484
# epoch 200 loss 43.060546875
# epoch 300 loss 39.28156280517578
# epoch 400 loss 36.92509078979492
# epoch 500 loss 35.13621520996094
# epoch 600 loss 33.70621871948242
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 45.58423614501953
# epoch 200 loss 36.42249298095703
# epoch 300 loss 32.97966003417969
# epoch 400 loss 30.86077880859375
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 39.67576599121094
# epoch 200 loss 32.37228012084961
# epoch 300 loss 29.897897720336914
# Early stopping due to small loss difference!
# Testing error: 0.0000
# epoch 100 loss 38.57541275024414
# epoch 200 loss 35.28583908081055
# epoch 300 loss 33.974185943603516
# epoch 400 loss 33.22618865966797
# epoch 500 loss 32.7081184387207
# epoch 600 loss 32.32654571533203
# epoch 700 loss 32.062110900878906
# Testing error: 0.0000
# epoch 100 loss 55.687232971191406
# Early stopping due to small loss difference!
# Testing error: 0.0100
# 1.0
# 71.42857142857143
# 0.003
# tensor([[[0.2800, 0.2500, 0.1300, 0.0700, 0.1100],
#          [0.1700, 0.1100, 0.1400, 0.0900, 0.0500],
#          [0.1400, 0.1900, 0.0800, 0.0900, 0.0800],
#          [0.2200, 0.1400, 0.0900, 0.0800, 0.0800],
#          [0.1400, 0.1400, 0.1000, 0.1300, 0.0200],
#          [0.1900, 0.0600, 0.0500, 0.0500, 0.0800],
#          [0.2000, 0.0800, 0.0500, 0.0800, 0.0500],
#          [0.1500, 0.0500, 0.0800, 0.0400, 0.0100]],
#
#         [[0.1400, 0.1000, 0.0400, 0.0400, 0.0300],
#          [0.0800, 0.1000, 0.0300, 0.0500, 0.0300],
#          [0.1200, 0.0400, 0.0500, 0.0100, 0.0100],
#          [0.0600, 0.0200, 0.0200, 0.0200, 0.0100],
#          [0.0700, 0.0400, 0.0400, 0.0100, 0.0200],
#          [0.0600, 0.0200, 0.0100, 0.0300, 0.0200],
#          [0.1700, 0.0100, 0.0100, 0.0100, 0.0100],
#          [0.0700, 0.0200, 0.0200, 0.0200, 0.0100]],
#
#         [[0.0700, 0.0100, 0.0200, 0.0300, 0.0300],
#          [0.0100, 0.0100, 0.0100, 0.0100, 0.0300],
#          [0.0500, 0.0200, 0.0200, 0.0100, 0.0100],
#          [0.0100, 0.0300, 0.0000, 0.0300, 0.0100],
#          [0.0300, 0.0000, 0.0200, 0.0000, 0.0100],
#          [0.0100, 0.0200, 0.0000, 0.0100, 0.0000],
#          [0.0200, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0200, 0.0100, 0.0100, 0.0000, 0.0000]],
#
#         [[0.0200, 0.0100, 0.0100, 0.0000, 0.0200],
#          [0.0200, 0.0000, 0.0000, 0.0000, 0.0200],
#          [0.0100, 0.0100, 0.0000, 0.0000, 0.0000],
#          [0.0100, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0100, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0100, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0100, 0.0000, 0.0000, 0.0000],
#          [0.0100, 0.0200, 0.0000, 0.0000, 0.0100]],
#
#         [[0.0100, 0.0000, 0.0000, 0.0400, 0.0600],
#          [0.0100, 0.0000, 0.0000, 0.0000, 0.0100],
#          [0.0100, 0.0000, 0.0000, 0.0000, 0.0300],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0100, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000]],
#
#         [[0.0000, 0.0000, 0.0100, 1.0000, 1.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 1.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 1.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0100]]])

# %%
# Hidden Test 9: testCase_cv
# ---------------------------
# This tests whether the best hyperparameters found by cross validation are correct for an example dataset.

# %%
CList=(2.0**np.linspace(-2,3,6))
lmbdaList=np.linspace(80, 115, 8)
lrList=(np.linspace(0.001,0.005,5))
print(CList)
print(lmbdaList)
print(lrList)
# Out:
# [0.25 0.5  1.   2.   4.   8.  ]
# [ 80.  85.  90.  95. 100. 105. 110. 115.]
# [0.001 0.002 0.003 0.004 0.005]

# %% [markdown]
# <h3>Competition</h3>
#
#
# We ask you to implement function autosvm, which given xTr and yTr, splits them into training data and validation data, and then uses a hyperparameter search to find the optimal hyper parameters.
#
# Function autosvm should return a function which will act as a classifier on xTe.
#
# You have a 5 minute time limit on multiple datasets, each dataset having different optimal hyperparameters, so you should strive for a good method of finding hyperparameters (within the time limit) instead of just trying to find a static set of good hyperparameters.
#
# You will get full credit for the competition if you can beat the base benchmark of <b>46% error</b> (you will get partial credit if you beat <b>50% error</b>).

# %%
def fasterDualSVM(xTr, yTr, kernel_type, kernel_matrix, num_epochs=100, C=1, lmbda=0, lr=1e-3, print_freq=100 ):
    ndims = xTr.shape[0]
    min_loss = np.inf
    loss_diff_threshold = 1e-2
    
    svmclassify = KernelizedSVM(ndims, kernel_type, lmbda)  # initialize the model
    optimizer = optim.SGD(svmclassify.parameters(), lr=lr)  # create an SGD optimizer for the model parameters
    
    for epoch in range(num_epochs):
        # need to zero the gradients in the optimizer so we don't
        # use the gradients from previous iterations
        
        #pred = svmclassify.forward(xTr, xTr)  # compute model predictions
        
        loss = kernelsvm_loss(svmclassify, kernel_matrix, yTr, C)
        optimizer.zero_grad()
        loss.backward()  # compute the gradient wrt loss
        optimizer.step()  # performs a step of gradient descent
        # if (epoch + 1) % print_freq == 0:
        #     print('epoch {} loss {}'.format(epoch+1, loss.item()))
        if abs(min_loss - loss.item()) < loss_diff_threshold or loss.item() == np.inf or loss.item()== np.nan :
            #print('Early stopping due to small loss difference!')
            break
        min_loss = loss.item()
    
    return lambda x: svmclassify.forward(xTr,x).flatten()

# %%
def autosvm(xTr,yTr, print_freq=100):
    """
    svmclassify = autosvm(xTr,yTr), where yTe = svmclassify(xTe)
    """
    xTr = xTr.float()
    yTr = yTr.float()

    ind = torch.randperm(len(xTr))

    tr_size = int(0.8 * len(xTr))  # 80% of the data

    x_train = xTr[ind[:tr_size]]
    y_train = yTr[ind[:tr_size]]
    x_test = xTr[ind[tr_size:]]
    y_test = yTr[ind[tr_size:]]
    
    CList=(2.0**np.linspace(-2,3,6))
    gamma_value1 = (1 / (xTr.shape[1] * xTr.var())).item()
    
    gamma_value2 = 1 / xTr.shape[1] 
    lmbdaList= [gamma_value1, gamma_value2, 0.001, 0.01, 0.1, 1, 10, 50, 100]
    print(lmbdaList)
    lrList=(np.linspace(0.001,0.006,6))

    bestC = torch.inf
    bestLmbda = torch.inf
    bestLr = torch.inf
    ErrorMatrix = torch.zeros(size=(len(lmbdaList), len(CList), len(lrList)))
    for j, lmbda in enumerate(lmbdaList):
        kernel_matrix = computeK('rbf', x_train, x_train, lmbda)
        for i, c in enumerate(CList):
            for k, lr in enumerate(lrList):

                trainModel=fasterDualSVM(x_train, y_train, kernel_type=ktype,kernel_matrix = kernel_matrix, num_epochs=1000, C=c, lmbda=lmbda, lr=lr)
                
                predsTe=trainModel(x_test)
                testingerr=torch.mean((torch.sign(predsTe)!=y_test).float())
                #print("Testing error: %2.4f" % testingerr)
                ErrorMatrix[j, i, k] = testingerr
                
                
    min_error_idx = torch.argmin(ErrorMatrix)  # Get the index of the minimum error
    j, i, k = np.unravel_index(min_error_idx, ErrorMatrix.shape)  # Convert the index to 3D

    bestC = CList[i]
    bestLmbda = lmbdaList[j]
    bestLr = lrList[k]
    
    print(f"Best C: {bestC}")
    print(f"Best Lambda: {bestLmbda}")
    print(f"Best Learning Rate: {bestLr}")
    print(ErrorMatrix)
    best_kernel_matrix = computeK('rbf', xTr, xTr, bestLmbda)
    tunedModel = fasterDualSVM(xTr, yTr, kernel_type='rbf',kernel_matrix = best_kernel_matrix, num_epochs=700, C=bestC, lmbda=bestLmbda, lr=bestLr)
    
    return tunedModel

# %%
gamma_value1 = (1 / (xTr.shape[1] * xTr.var())).item()
    
gamma_value2 = 1 / xTr.shape[1] 
# Increase the range
lmbdaList = [gamma_value1, gamma_value2, 1e-5, 1e-4, 0.001, 0.01, 0.1, 0.6, 1, 10, 50, 100, 500, 1000]
print(lmbdaList)

# Increase the number of values
lmbdaList = [gamma_value1, gamma_value2, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100]
print(lmbdaList)

# Use a logarithmic scale
lmbdaList = np.logspace(-5, 3, 9).tolist()
lmbdaList = [gamma_value1, gamma_value2] + lmbdaList
print(lmbdaList)
# Out:
# [8.935322761535645, 0.5, 1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 50, 100, 500, 1000]
# [8.935322761535645, 0.5, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100]
# [8.935322761535645, 0.5, 1e-05, 0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]

# %%
tuned=autosvm(xTr, yTr)
visclassifier.visclassifier(tuned,xTr,yTr)

# compute training and testing error
predsTr=tuned(xTr)
trainingerr=torch.mean((torch.sign(predsTr)!=yTr).float())
print("Training error: %2.4f" % trainingerr)

predsTe=tuned(xTe)
testingerr=torch.mean((torch.sign(predsTe)!=yTe).float())
print("Testing error: %2.4f" % testingerr)
# Out:
# [8.935322761535645, 0.5, 0.001, 0.01, 0.1, 1, 10, 50, 100]
# Best C: 1.0
# Best Lambda: 100
# Best Learning Rate: 0.001
# tensor([[[0.6000, 0.4500, 0.4500, 0.5000, 0.4500, 0.5500],
#          [0.4500, 0.5500, 0.5500, 0.6000, 0.5500, 0.5500],
#          [0.4000, 0.6000, 0.4500, 0.4500, 0.4500, 0.5500],
#          [0.4500, 0.4500, 0.5500, 0.5500, 0.5500, 0.5500],
#          [0.4500, 0.4500, 0.4500, 0.4500, 0.4500, 0.5500],
#          [0.4500, 0.4500, 0.5500, 0.4500, 0.5500, 0.4500]],
#
#         [[0.4000, 0.5500, 0.5500, 0.5500, 0.4500, 0.4500],
#          [0.4500, 0.5500, 0.5500, 0.5500, 0.4500, 0.4500],
#          [0.5500, 0.4500, 0.4500, 0.5500, 0.5500, 0.4500],
#          [0.4500, 0.4500, 0.4500, 0.5500, 0.4500, 0.5500],
#          [0.4500, 0.5500, 0.4500, 0.5500, 0.4500, 0.5500],
#          [0.5500, 0.5500, 0.5500, 0.5500, 0.5500, 0.4500]],
#
#         [[0.4500, 0.5500, 0.4500, 0.4500, 0.4500, 0.4500],
#          [0.4500, 0.5500, 0.5500, 0.5500, 0.4500, 0.5500],
#          [0.5500, 0.4500, 0.4500, 0.5500, 0.4500, 0.5500],
#          [0.4500, 0.4500, 0.5500, 0.4500, 0.4500, 0.4500],
#          [0.4500, 0.4500, 0.4500, 0.4500, 0.4500, 0.5500],
#          [0.5500, 0.5500, 0.4500, 0.4500, 0.5500, 0.4500]],
#
#         [[0.4500, 0.4500, 0.4500, 0.5500, 0.4500, 0.4500],
#          [0.4500, 0.5500, 0.5500, 0.5500, 0.5500, 0.5500],
#          [0.5500, 0.4500, 0.5500, 0.5500, 0.4500, 0.5500],
#          [0.5500, 0.4500, 0.5500, 0.4500, 0.5500, 0.4500],
#          [0.5500, 0.5500, 0.5500, 0.4500, 0.4500, 0.4500],
#          [0.5500, 0.4500, 0.4500, 0.4500, 0.5500, 0.4500]],
#
#         [[0.4500, 0.4500, 0.4500, 0.5500, 0.4500, 0.5500],
#          [0.5500, 0.4500, 0.5500, 0.5500, 0.4500, 0.4500],
#          [0.5500, 0.5500, 0.4500, 0.4500, 0.4500, 0.4500],
#          [0.5500, 0.4500, 0.4500, 0.5500, 0.5500, 0.4500],
#          [0.4500, 0.4500, 0.5500, 0.5500, 0.5500, 0.4500],
#          [0.5500, 0.5500, 0.5500, 0.5500, 0.4500, 0.4500]],
#
#         [[0.3500, 0.5500, 0.4500, 0.4500, 0.5500, 0.4500],
#          [0.5500, 0.5500, 0.4500, 0.4500, 0.5500, 0.4500],
#          [0.5500, 0.5500, 0.4500, 0.4500, 0.4500, 0.4500],
#          [0.5500, 0.4500, 0.5500, 0.5500, 0.5500, 0.4500],
#          [0.4500, 0.4500, 0.4500, 0.4500, 0.5500, 0.5500],
#          [0.5500, 0.5500, 0.4500, 0.5500, 0.4500, 0.5500]],
#
#         [[0.4500, 0.5000, 0.7000, 0.7000, 0.5000, 0.5500],
#          [0.4500, 0.6000, 0.3500, 0.5500, 0.5500, 0.4500],
#          [0.4500, 0.6000, 0.4500, 0.4500, 0.5500, 0.4500],
#          [0.4500, 0.4500, 0.4500, 0.4500, 0.4500, 0.4500],
#          [0.4500, 0.5500, 0.4500, 0.5500, 0.5500, 0.4500],
#          [0.4500, 0.4500, 0.4500, 0.5500, 0.5500, 0.4500]],
#
#         [[0.3500, 0.2500, 0.3500, 0.3500, 0.5500, 0.2500],
#          [0.2500, 0.3500, 0.1500, 0.2000, 0.1500, 0.2000],
#          [0.1500, 0.3000, 0.2500, 0.2000, 0.2000, 0.2000],
#          [0.3000, 0.2000, 0.2500, 0.2000, 0.1500, 0.1500],
#          [0.2500, 0.2000, 0.1500, 0.1500, 0.1500, 0.1500],
#          [0.2000, 0.1500, 0.2000, 0.2000, 0.1500, 0.5500]],
#
#         [[0.1000, 0.3000, 0.2500, 0.2000, 0.3000, 0.4500],
#          [0.1500, 0.1500, 0.2000, 0.3000, 0.1000, 0.1500],
#          [0.0500, 0.2500, 0.1500, 0.1500, 0.0500, 0.0500],
#          [0.1000, 0.2000, 0.0500, 0.2000, 0.0500, 0.1500],
#          [0.0500, 0.1500, 0.0500, 0.1000, 0.1500, 0.0500],
#          [0.1500, 0.0500, 0.1000, 0.1000, 0.1000, 0.2000]]])
# Training error: 0.0100
# Testing error: 0.0167

# %%
# Hidden Test 11: competition
# ---------------------------
# This tests the error rate of your classifier on the competition datasets 
# (remember each cell in this notebook should run in < 5 minutes!)

# %%
# Prints out the summary of tests passed/failed.
